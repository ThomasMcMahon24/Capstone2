# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.model_selection import train_test_split 
from sklearn import linear_model, preprocessing

# %%
os.chdir('C:\\Users\\tommc\\OneDrive\\Documents\\GitHub\\Baseball')

# %%
data = pd.read_excel('final_clean_data.xlsx', index_col=0)

# %%
data.head()
# Out:
#         playerID  yearID   AB    H  2B  3B  HR   SO   BB  total_hits  \
# 22164   mayswi01    1970  478  139  15   2  28   90   79         184
# 22165   mayswi01    1971  417  113  24   5  18  123  112         160
# 22166   mayswi01    1972  195   52   9   1   8   43   43          70
# 22167   mayswi01    1973  209   44  10   0   6   47   27          60
# 22949  aaronha01    1970  516  154  26   1  38   63   74         219
#
#              BA  birthYear  age  last year BA
# 22164  0.384937       1931   39      0.364764
# 22165  0.383693       1931   40      0.384937
# 22166  0.358974       1931   41      0.383693
# 22167  0.287081       1931   42      0.358974
# 22949  0.424419       1934   36      0.440585

# %%
data.corr()
# Out:
#                 yearID        AB         H        2B        3B        HR  \
# yearID        1.000000  0.005267  0.012843  0.115186 -0.069757  0.101174
# AB            0.005267  1.000000  0.983557  0.903877  0.579654  0.698856
# H             0.012843  0.983557  1.000000  0.921110  0.590773  0.705130
# 2B            0.115186  0.903877  0.921110  1.000000  0.481289  0.708197
# 3B           -0.069757  0.579654  0.590773  0.481289  1.000000  0.248447
# HR            0.101174  0.698856  0.705130  0.708197  0.248447  1.000000
# SO            0.186991  0.786366  0.740520  0.730474  0.398799  0.764945
# BB           -0.010407  0.796908  0.790345  0.746752  0.401585  0.719301
# total_hits    0.037534  0.977811  0.993851  0.943836  0.577033  0.767088
# BA            0.124231  0.541023  0.622621  0.653749  0.353251  0.569212
# birthYear     0.951621  0.000914  0.007302  0.105598 -0.031291  0.082769
# age           0.097475  0.013786  0.017187  0.024232 -0.120456  0.053622
# ...

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(40,20))

sns.heatmap(data.corr(),annot = True)

# %%
sns.jointplot(x='AB',y='BA',data=data,kind='reg')

# %%
sns.jointplot(x='last year BA',y='BA',data=data,kind='reg')

# %%
sns.jointplot(x='SO',y='BA',data=data,kind='reg')

# %%
sns.jointplot(x='BB',y='BA',data=data,kind='reg')

# %%
sns.jointplot(x='SO',y='BB',data=data,kind='reg')
